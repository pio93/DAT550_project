# %%
import pandas as pd
from scripts import preprocessing

# %%
df = pd.read_csv('data/train.csv')

# %%
preprocessing.pre_proc(df)

# %%
df
# Out:
#             id    tid1    tid2  \
# 0            0       0       1
# 1            3       2       3
# 2            1       2       4
# 3            2       2       5
# 4            9       6       7
# ...        ...     ...     ...
# 320547  321185  167562  114783
# 320548  321182  167562  114782
# 320549  321184  167562  137705
# 320550  321186  167562   48989
# 320551  321188  167563   66480
#
#                                                 title1_en  \
# 0       There are two new old-age insurance benefits f...
# 1       "If you do not come to Shenzhen, sooner or lat...
# 2       "If you do not come to Shenzhen, sooner or lat...
# 3       "If you do not come to Shenzhen, sooner or lat...
# 4       "How to discriminate oil from gutter oil by me...
# ...                                                   ...
# 320547  egypt 's presidential election failed to win m...
# 320548  egypt 's presidential election failed to win m...
# 320549  egypt 's presidential election failed to win m...
# 320550  egypt 's presidential election failed to win m...
# 320551  Will the United States wage war on Iraq withou...
#
#                                                 title2_en      label
# 0       Police disprove "bird's nest congress each per...  unrelated
# 1       Shenzhen's GDP outstrips Hong Kong? Shenzhen S...  unrelated
# 2       The GDP overtopped Hong Kong? Shenzhen clarifi...  unrelated
# 3       Shenzhen's GDP topped Hong Kong last year? She...  unrelated
# 4       It took 30 years of cooking oil to know that o...    related
# ...                                                   ...        ...
# 320547  West Media Exposing Tallahlach has been recomm...  unrelated
# 320548  Salah agent's dishonest rumour: rumour with ba...  unrelated
# 320549  Rumor has it that Egypt is very united and the...  unrelated
# 320550  False rumors, Egypt Football Association Chair...  unrelated
# 320551  Saddam's daughter refutes rumors: no. 2 of Sad...  unrelated
#
# [320552 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

def dec_tree(df, dat_type):
    data = df.drop(['id', 'tid1', 'tid2'], axis=1)
    x = data.iloc[:, :-1]
    y = data.iloc[:, -1]

    encoder = LabelEncoder()
    encoder.fit_transform(x)
    
    scaler = StandardScaler()
    scaler.fit_transform(x)

# %%
dec_tree(df, 'train')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-8c4795799aec> in <module>
# ----> 1 dec_tree(df, 'train')
#
# <ipython-input-11-43b7ed4fc2ef> in dec_tree(df, dat_type)
#       7
#       8     encoder = LabelEncoder()
# ----> 9     encoder.fit(x)
#      10
#      11     scaler = StandardScaler()
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\preprocessing\_label.py in fit(self, y)
#     237         self : returns an instance of self.
#     238         """
# --> 239         y = column_or_1d(y, warn=True)
#     240         self.classes_ = _encode(y)
#     241         return self
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#     845     raise ValueError(
#     846         "y should be a 1d array, "
# --> 847         "got an array of shape {} instead.".format(shape))
#     848
#     849
#
# ValueError: y should be a 1d array, got an array of shape (320552, 2) instead.
